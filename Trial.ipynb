# %%
from data_loader import DataLoader
from my_module import Plotting
from my_module import StadiumAnalysis
from my_module import TabularAnalysis

def main():
    file_path = "t20-world-cup-22.csv"
    data_loader = DataLoader(file_path)
    
    plotting = Plotting(data_loader.data)
    stadium_plotting=StadiumAnalysis(data_loader.data)
    Table=TabularAnalysis(data_loader.data)
    
    while True:
        print("\nChoose an option:")
        print("1. Plot Team Wins")
        print("2. Plot Matches Won by Runs or Wickets")
        print("3. Plot Toss Decision")
        print("4. Plot Top Scorers")
        print("5. Plot Player of the Match")
        print("6. Plot Best Bowlers")
        print("7. Plot Stadiums to Bat or Chase")
        print("8. Plot Stadiums to Bowl or Defend")
        print("9. Display Relevant Data Tables")
        print("0. Exit")

        choice = input("Enter your choice (0-9): ")

        if choice == "0":
            print("Exiting the program. Goodbye!")
            break
        elif choice == "1":
            plotting.plot_team_wins()
        elif choice == "2":
            plotting.plot_matches_won_by_runs_or_wickets()
        elif choice == "3":
            plotting.plot_toss_decisions()
        elif choice == "4":
            num_players = int(input("Enter the number of top scorers to display: "))
            plotting.plot_top_scorers(num_players)
        elif choice == "5":
            
            plotting.plot_player_of_the_match()
        elif choice == "6":
            
            plotting.plot_best_bowlers()
        elif choice == "7":
            stadium_plotting.plot_best_stadiums_batting()
    
        elif choice == "8":
            stadium_plotting.plot_stadiums_to_bowl_or_defend()
        elif choice == '9':
            print("\nChoose an option:")
            print("1. Team Wins")
            
            print("2. Top Scorers")
            print("3. Player of the Match")
           
            print("4. Stadiums ")
            
            print("0. Exit")
            choice = input("Enter your choice (0-4): ")

            if choice == "0":
                print("Exiting the program. Goodbye!")
                break
            elif choice == "1":
                 Table.display_team_wins_table()
            
            elif choice == "2":
                
                Table.display_top_scorers_table()
            elif choice == "3":
                
                Table.display_player_of_the_match_table()
           
            elif choice == "4":
               Table.display_stadiums_table()
            
            else:
                print("Invalid choice. Please enter a number between 0 and 4.")
            
        else:
            print("Invalid choice. Please enter a number between 0 and 9.")

if __name__ == "__main__":
    main()
# Out:
# Choose an option:
# 1. Plot Team Wins
# 2. Plot Matches Won by Runs or Wickets
# 3. Plot Toss Decision
# 4. Plot Top Scorers
# 5. Plot Player of the Match
# 6. Plot Best Bowlers
# 7. Plot Stadiums to Bat or Chase
# 8. Plot Stadiums to Bowl or Defend
# 9. Display Relevant Data Tables
# 0. Exit
# Choose an option:
# 1. Plot Team Wins
# 2. Plot Matches Won by Runs or Wickets
# 3. Plot Toss Decision
# 4. Plot Top Scorers
# 5. Plot Player of the Match
# 6. Plot Best Bowlers
# 7. Plot Stadiums to Bat or Chase
# 8. Plot Stadiums to Bowl or Defend
# 9. Display Relevant Data Tables
# 0. Exit
# Choose an option:
# 1. Plot Team Wins
# 2. Plot Matches Won by Runs or Wickets
# 3. Plot Toss Decision
# 4. Plot Top Scorers
# 5. Plot Player of the Match
# 6. Plot Best Bowlers
# 7. Plot Stadiums to Bat or Chase
# 8. Plot Stadiums to Bowl or Defend
# 9. Display Relevant Data Tables
# 0. Exit
# Choose an option:
# 1. Plot Team Wins
# 2. Plot Matches Won by Runs or Wickets
# 3. Plot Toss Decision
# 4. Plot Top Scorers
# 5. Plot Player of the Match
# 6. Plot Best Bowlers
# 7. Plot Stadiums to Bat or Chase
# 8. Plot Stadiums to Bowl or Defend
# 9. Display Relevant Data Tables
# 0. Exit
# Choose an option:
# 1. Plot Team Wins
# 2. Plot Matches Won by Runs or Wickets
# 3. Plot Toss Decision
# 4. Plot Top Scorers
# 5. Plot Player of the Match
# 6. Plot Best Bowlers
# 7. Plot Stadiums to Bat or Chase
# 8. Plot Stadiums to Bowl or Defend
# 9. Display Relevant Data Tables
# 0. Exit
# Choose an option:
# 1. Plot Team Wins
# 2. Plot Matches Won by Runs or Wickets
# 3. Plot Toss Decision
# 4. Plot Top Scorers
# 5. Plot Player of the Match
# 6. Plot Best Bowlers
# 7. Plot Stadiums to Bat or Chase
# 8. Plot Stadiums to Bowl or Defend
# 9. Display Relevant Data Tables
# 0. Exit
# Choose an option:
# 1. Plot Team Wins
# 2. Plot Matches Won by Runs or Wickets
# 3. Plot Toss Decision
# 4. Plot Top Scorers
# 5. Plot Player of the Match
# 6. Plot Best Bowlers
# 7. Plot Stadiums to Bat or Chase
# 8. Plot Stadiums to Bowl or Defend
# 9. Display Relevant Data Tables
# 0. Exit
# Choose an option:
# 1. Plot Team Wins
# 2. Plot Matches Won by Runs or Wickets
# 3. Plot Toss Decision
# 4. Plot Top Scorers
# 5. Plot Player of the Match
# 6. Plot Best Bowlers
# 7. Plot Stadiums to Bat or Chase
# 8. Plot Stadiums to Bowl or Defend
# 9. Display Relevant Data Tables
# 0. Exit
#
# Choose an option:
# 1. Team Wins
# 2. Top Scorers
# 3. Player of the Match
# 4. Stadiums
# 0. Exit
#
# Team Wins Table:
#             Team  Number of Matches Won
# 0        England                      5
# 1          India                      4
# 2       Pakistan                      4
# 3    New Zealand                      3
# 4      Australia                      3
# 5      Sri lanka                      2
# 6     Bangladesh                      2
# 7   South Africa                      2
# 8    Netherlands                      2
# 9        Ireland                      1
# 10      Zimbabwe                      1
#
# Choose an option:
# 1. Plot Team Wins
# 2. Plot Matches Won by Runs or Wickets
# 3. Plot Toss Decision
# 4. Plot Top Scorers
# 5. Plot Player of the Match
# 6. Plot Best Bowlers
# 7. Plot Stadiums to Bat or Chase
# 8. Plot Stadiums to Bowl or Defend
# 9. Display Relevant Data Tables
# 0. Exit
#
# Choose an option:
# 1. Team Wins
# 2. Top Scorers
# 3. Player of the Match
# 4. Stadiums
# 0. Exit
#
# Top 5 Scorers Table:
#            Player  Highest Score
# 0   Rilee Rossouw          109.0
# 1  Glenn Phillips          104.0
# 2    Devon Conway           92.0
# 3      Alex Hales           86.0
# 4     Virat Kohli           82.0
#
# Choose an option:
# 1. Plot Team Wins
# 2. Plot Matches Won by Runs or Wickets
# 3. Plot Toss Decision
# 4. Plot Top Scorers
# 5. Plot Player of the Match
# 6. Plot Best Bowlers
# 7. Plot Stadiums to Bat or Chase
# 8. Plot Stadiums to Bowl or Defend
# 9. Display Relevant Data Tables
# 0. Exit
#
# Choose an option:
# 1. Team Wins
# 2. Top Scorers
# 3. Player of the Match
# 4. Stadiums
# 0. Exit
#
# Top 5 Players with Player of the Match Awards Table:
#              Player  Number of Player of the Match Awards
# 0       Virat Kohli                                     2
# 1      Taskin Ahmed                                     2
# 2  Suryakumar Yadav                                     2
# 3       Shadab Khan                                     2
# 4        Sam Curran                                     2
#
# Choose an option:
# 1. Plot Team Wins
# 2. Plot Matches Won by Runs or Wickets
# 3. Plot Toss Decision
# 4. Plot Top Scorers
# 5. Plot Player of the Match
# 6. Plot Best Bowlers
# 7. Plot Stadiums to Bat or Chase
# 8. Plot Stadiums to Bowl or Defend
# 9. Display Relevant Data Tables
# 0. Exit
#
# Choose an option:
# 1. Team Wins
# 2. Top Scorers
# 3. Player of the Match
# 4. Stadiums
# 0. Exit
#
# Stadiums Data Table:
#                venue  first innings score  second innings score  \
# 0                SCG                200.0                 111.0
# 1      Optus Stadium                112.0                 113.0
# 2   Blundstone Arena                128.0                 133.0
# 3                MCG                159.0                 160.0
# 4   Blundstone Arena                144.0                 135.0
# 5   Blundstone Arena                 79.0                  51.0
# 6      Optus Stadium                157.0                 158.0
# 7                MCG                157.0                 105.0
# 8                MCG                  NaN                   NaN
# 9                SCG                205.0                 101.0
# 10               SCG                179.0                 123.0
# 11     Optus Stadium                130.0                 129.0
# 12               MCG                  NaN                   NaN
# 13               MCG                  NaN                   NaN
# 14               SCG                167.0                 102.0
# 15         The Gabba                150.0                 147.0
# 16     Optus Stadium                 91.0                  95.0
# 17     Optus Stadium                133.0                 137.0
# 18         The Gabba                179.0                 137.0
# 19         The Gabba                144.0                 148.0
# 20         The Gabba                179.0                 159.0
# 21     Adelaide Oval                117.0                 120.0
# 22     Adelaide Oval                184.0                 145.0
# 23               SCG                185.0                 108.0
# 24     Adelaide Oval                185.0                 150.0
# 25     Adelaide Oval                168.0                 164.0
# 26               SCG                141.0                 144.0
# 27     Adelaide Oval                158.0                 145.0
# 28     Adelaide Oval                127.0                 128.0
# 29               MCG                186.0                 115.0
# 30               SCG                152.0                 153.0
# 31     Adelaide Oval                168.0                 170.0
# 32               MCG                137.0                 138.0
#
#     first innings wickets  second innings wickets
# 0                     3.0                    10.0
# 1                    10.0                     5.0
# 2                     8.0                     1.0
# 3                     8.0                     6.0
# 4                     8.0                    10.0
# 5                     5.0                     0.0
# 6                     6.0                     3.0
# 7                    10.0                     5.0
# 8                     NaN                     NaN
# 9                     5.0                    10.0
# 10                    2.0                     9.0
# 11                    8.0                     8.0
# 12                    NaN                     NaN
# 13                    NaN                     NaN
# 14                    7.0                    10.0
# 15                    7.0                     8.0
# 16                    9.0                     4.0
# 17                    9.0                     5.0
# 18                    5.0                    10.0
# 19                    8.0                     4.0
# 20                    6.0                     6.0
# 21                   10.0                     5.0
# 22                    6.0                     6.0
# 23                    9.0                     9.0
# 24                    6.0                     9.0
# 25                    8.0                     7.0
# 26                    8.0                     6.0
# 27                    4.0                     8.0
# 28                    8.0                     5.0
# 29                    5.0                    10.0
# 30                    4.0                     3.0
# 31                    6.0                     0.0
# 32                    8.0                     5.0
#
# Choose an option:
# 1. Plot Team Wins
# 2. Plot Matches Won by Runs or Wickets
# 3. Plot Toss Decision
# 4. Plot Top Scorers
# 5. Plot Player of the Match
# 6. Plot Best Bowlers
# 7. Plot Stadiums to Bat or Chase
# 8. Plot Stadiums to Bowl or Defend
# 9. Display Relevant Data Tables
# 0. Exit
# Exiting the program. Goodbye!
